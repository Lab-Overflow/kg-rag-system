# %% [markdown]
# # KG-RAG 实验
# - 加载 seed 数据
# - 运行 agentic 查询
# - 可视化子图 + 检索前后的 RAGAS 指标

# %%
import asyncio, httpx
r = httpx.post('http://localhost:8000/api/query', json={'q':'Who founded Anthropic?', 'mode':'agentic'}).json()
print(r['answer'])
